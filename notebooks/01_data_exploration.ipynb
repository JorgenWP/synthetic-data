# %% [markdown]
# # Data Exploration
#
# This notebook demonstrates how to load and explore transactional data before converting it to graph format.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from src.data import DataLoader

# %matplotlib inline
sns.set_style('whitegrid')

# %% [markdown]
# ## Load Data
#
# Load your transactional data using the DataLoader.

# %%
# Initialize data loader
data_loader = DataLoader(data_dir='../data/raw')

# TODO: Load your data
# df = data_loader.load_transactions('your_data.csv')
# print(f"Loaded {len(df)} transactions")
# df.head()

# %% [markdown]
# ## Data Statistics
#
# Compute basic statistics about your transactional data.

# %%
# TODO: Add your data exploration code
# df.describe()
# df.info()

# %% [markdown]
# ## Visualize Data Distribution

# %%
# TODO: Add visualization code
# Example:
# plt.figure(figsize=(12, 6))
# plt.hist(df['transaction_amount'], bins=50)
# plt.xlabel('Transaction Amount')
# plt.ylabel('Frequency')
# plt.title('Transaction Amount Distribution')
# plt.show()
