# %% [markdown]
# # Graph Preprocessing
#
# This notebook demonstrates how to convert transactional data into graph representations.

# %%
import sys
sys.path.insert(0, '..')

import pandas as pd
import networkx as nx
import matplotlib.pyplot as plt

from src.data import DataLoader, GraphPreprocessor
from src.utils.visualization import visualize_graph

# %matplotlib inline

# %% [markdown]
# ## Load Data

# %%
# TODO: Load your transactional data
# data_loader = DataLoader(data_dir='../data/raw')
# df = data_loader.load_transactions('your_data.csv')

# %% [markdown]
# ## Convert to Graph

# %%
# Initialize preprocessor
preprocessor = GraphPreprocessor()

# TODO: Build graph from your data
# Specify the column names that represent source and target nodes
# G = preprocessor.build_graph_from_transactions(
#     df,
#     source_col='source_node',
#     target_col='target_node',
#     edge_attrs=['transaction_amount', 'timestamp']
# )

# %% [markdown]
# ## Graph Statistics

# %%
# TODO: Compute graph statistics
# stats = preprocessor.compute_graph_statistics(G)
# for key, value in stats.items():
#     print(f"{key}: {value}")

# %% [markdown]
# ## Visualize Graph

# %%
# TODO: Visualize the graph
# visualize_graph(G, title='Transaction Graph', figsize=(15, 10))
# plt.show()

# %% [markdown]
# ## Extract Features

# %%
# TODO: Extract node features
# features = preprocessor.extract_node_features(G)
# print(f"Feature matrix shape: {features.shape}")
# print(f"Sample features: {features[:5]}")
